# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math as m
import pandas_datareader.data as web

# %%
df1 = pd.read_csv('C:\workspace\python2\Project1/crime.csv')
df1
# Out:
#         Unnamed: 0   2012 2012.1  2012.2  2012.3 2012.4 2012.5 2012.6  \
# 0              NaN      M      M       M       M      M      M      M
# 1               죄종    u20    u30     u40     u50    u60    u70    o70
# 2         강력범죄살인기수      8     46      79      93     85     24     10
# 3        강력범죄살인미수등     18     76     100     193    109     28     17
# 4           강력범죄강도    991    801     635     416    172     35     10
# 5      강력범죄강간·강제추행   2892   3886    3796    3670   2354    747    294
# 6           강력범죄강간    NaN    NaN     NaN     NaN    NaN    NaN    NaN
# 7         강력범죄유사강간    NaN    NaN     NaN     NaN    NaN    NaN    NaN
# 8         강력범죄강제추행    NaN    NaN     NaN     NaN    NaN    NaN    NaN
# 9   강력범죄기타강간·강제추행등    NaN    NaN     NaN     NaN    NaN    NaN    NaN
# 10          강력범죄방화    207     95     193     384    286     46     19
# 11            절도범죄  36778  13508   10245   10752   8378   3009   1245
# ...

# %%
df1 = pd.read_csv('C:/workspace/python2/ccc.csv',header=[0,1,2],index_col= 0)
df1
# Out:
#                    2012                                                 \
#                       M
# 죄종                  u20      u30       u40       u50      u60      u70
# 강력범죄살인기수            8.0     46.0      79.0      93.0     85.0     24.0
# 강력범죄살인미수등          18.0     76.0     100.0     193.0    109.0     28.0
# 강력범죄강도            991.0    801.0     635.0     416.0    172.0     35.0
# 강력범죄강간·강제추행      2892.0   3886.0    3796.0    3670.0   2354.0    747.0
# 강력범죄강간              NaN      NaN       NaN       NaN      NaN      NaN
# 강력범죄유사강간            NaN      NaN       NaN       NaN      NaN      NaN
# 강력범죄강제추행            NaN      NaN       NaN       NaN      NaN      NaN
# 강력범죄기타강간·강제추행등      NaN      NaN       NaN       NaN      NaN      NaN
# 강력범죄방화            207.0     95.0     193.0     384.0    286.0     46.0
# 절도범죄            36778.0  13508.0   10245.0   10752.0   8378.0   3009.0
# 폭력범죄폭행           8282.0  22168.0   31170.0   41965.0  30015.0   7589.0
# ...

# %%
df1 = pd.read_csv('C:/workspace/python2/ccc.csv',header=[0,1,2],index_col= 0)
df1
df2 = df1.transpose()
df2
# Out:
#                 강력범죄살인기수  강력범죄살인미수등  강력범죄강도  강력범죄강간·강제추행  강력범죄강간  강력범죄유사강간  \
#        죄종
# 2012 M u20           8.0       18.0   991.0       2892.0     NaN       NaN
#        u30          46.0       76.0   801.0       3886.0     NaN       NaN
#        u40          79.0      100.0   635.0       3796.0     NaN       NaN
#        u50          93.0      193.0   416.0       3670.0     NaN       NaN
#        u60          85.0      109.0   172.0       2354.0     NaN       NaN
# ...                  ...        ...     ...          ...     ...       ...
# 2019 F u50          15.0       12.0    19.0        144.0    15.0       3.0
#        u60          17.0       16.0    15.0        133.0    17.0       3.0
#        u70           6.0        8.0     4.0         67.0    13.0       NaN
#        o70           4.0        2.0     6.0         10.0     NaN       NaN
#        unknown       1.0        NaN     1.0          6.0     1.0       1.0
#
# ...

# %%
df3 = df2.fillna(0)
df3
# Out:
#                 강력범죄살인기수  강력범죄살인미수등  강력범죄강도  강력범죄강간·강제추행  강력범죄강간  강력범죄유사강간  \
#        죄종
# 2012 M u20           8.0       18.0   991.0       2892.0     0.0       0.0
#        u30          46.0       76.0   801.0       3886.0     0.0       0.0
#        u40          79.0      100.0   635.0       3796.0     0.0       0.0
#        u50          93.0      193.0   416.0       3670.0     0.0       0.0
#        u60          85.0      109.0   172.0       2354.0     0.0       0.0
# ...                  ...        ...     ...          ...     ...       ...
# 2019 F u50          15.0       12.0    19.0        144.0    15.0       3.0
#        u60          17.0       16.0    15.0        133.0    17.0       3.0
#        u70           6.0        8.0     4.0         67.0    13.0       0.0
#        o70           4.0        2.0     6.0         10.0     0.0       0.0
#        unknown       1.0        0.0     1.0          6.0     1.0       1.0
#
# ...
